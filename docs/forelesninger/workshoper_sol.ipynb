# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("https://www.uio.no/studier/emner/matnat/ifi/IN-KJM1900/h20/datafiler/vin.csv")
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# 3      9.8        6
# 4      9.4        5

# %%
df2 = df[df["quality"] <= 5]

# %%
surhet = df["fixed acidity"]
pH = df["pH"]
snitt_pH = ph.mean()
ph_std = ph.std()
plt.scatter(surhet, pH)
plt.axhline(snitt_pH, color = 'red')
plt.axhline(snitt_pH + ph_std, color = 'orange')
plt.axhline(snitt_pH - ph_std, color = 'orange')
plt.xlabel("Innhold av vinsyre (g/L)")
plt.ylabel("pH")
plt.show()

# %%
ph.mean()
# Out:
# 3.311113195747343

# %%
a, b = np.polyfit(surhet, pH, 1)
x = np.linspace(3,20,1000)
y = a*x + b

# %%
surhet = df["fixed acidity"]
pH = df["pH"]
snitt_pH = ph.mean()
ph_std = ph.std()
plt.scatter(surhet, pH)
plt.plot(x,y,color="firebrick")
plt.xlabel("Innhold av vinsyre (g/L)")
plt.ylabel("pH")
plt.show()

# %%
vinsyreinnhold = 1

# %%
df2.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count     744.000000        744.000000   744.000000       744.00000
# mean        8.142204          0.589503     0.237755         2.54207
# std         1.572396          0.177956     0.183368         1.39355
# min         4.600000          0.180000     0.000000         1.20000
# 25%         7.100000          0.460000     0.080000         1.90000
# 50%         7.800000          0.590000     0.220000         2.20000
# 75%         8.900000          0.680000     0.360000         2.60000
# max        15.900000          1.580000     1.000000        15.50000
#
#         chlorides  free sulfur dioxide  total sulfur dioxide     density  \
# count  744.000000           744.000000            744.000000  744.000000
# mean     0.092989            16.567204             54.645161    0.997068
# std      0.055781            10.890291             36.720468    0.001598
# min      0.039000             3.000000              6.000000    0.992560
# 25%      0.074000             8.000000             23.750000    0.996120
# 50%      0.081000            14.000000             45.000000    0.996935
# 75%      0.094000            23.000000             78.000000    0.997900
# max      0.611000            68.000000            155.000000    1.003150
#
#                pH   sulphates     alcohol     quality
# count  744.000000  744.000000  744.000000  744.000000
# mean     3.311653    0.618535    9.926478    4.901882
# std      0.154296    0.176194    0.758007    0.339894
# min      2.740000    0.330000    8.400000    3.000000
# 25%      3.200000    0.520000    9.400000    5.000000
# 50%      3.310000    0.580000    9.700000    5.000000
# 75%      3.400000    0.650000   10.300000    5.000000
# max      3.900000    2.000000   14.900000    5.000000
